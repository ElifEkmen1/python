# %%
print("hello python")
# Out:
# hello python

# %%
list[1,2,3]
type(list)
# Out:
# type

# %%
list[1,2,3]
type(list)
# Out:
# type

# %% [markdown]
# ## First Notebook

# %%
## First Notebook

# %% [markdown]
# ##### First Notebook

# %%
course = "python programming"
print(len(course))
# Out:
# 18
